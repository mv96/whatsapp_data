# %%
#apple parsing
import numpy as np
import pandas as pd

file=input("enter the file that you want to open:")
fhand=open(file)

column_name=["date","time","sender","message"]
labels=[]
count=0

for rows in fhand:
    labels.append(count)
    count+=1
fhand.close()   

df=pd.DataFrame(columns=column_name,index=labels)
del(count,labels)
df.at[4, 'time']=4
#display(df)

fhand=open(file)

row=0
time_f=None #<<<< for some data sets turing this can save you
for line in fhand:
    line=line.strip()
    line=line.split("] ")
    time_stamp=line[0]
    time=time_stamp.split(",")
    #print(len(time[0]))
    type_1_length=(len(time[0])==len("[24/04/17"))
    type_2_length=(len(time[0])==len("[4/04/17"))
    type_3_length=(len(time[0])==len("[4/4/17"))
    type_1_position=(time[0].find("/")==3)
    type_2_position=(time[0].find("/")==2)
    if((type_1_length or type_2_length or type_3_length) and (type_1_position or type_2_position)): #if in proper date format
        time[0]=time[0][1:]
        date=time[0]
        #print(date)
        #print("in first if")
        time[1]=time[1].strip()#remove extra space
        if(len(time[1])==len("12:00:43 AM")):
            time_f=time[1]
        elif(len(time[1])==len("2:00:43 AM")):
            time_f="0"+time[1]
        try:
            body=line[1]
            body=body.strip()
            mark=body.find(":")
            sender=body[:mark]
            if("secur"not in sender):
                sender=body[:mark]
                #print(sender)
            else:
                sender=np.nan
            message=body[mark+1:]
            message=message.strip()
            #print(sender)
        except:
            message=str(line[0])
            #>>>>>add message to data frame
    else:
        #print("in first else")
        #print("this is the message:",time)
        message=time
        
    df.at[row, 'date']=date
    df.at[row, 'time']=time_f
    df.at[row, 'sender']=sender
    df.at[row, 'message']=message
    row+=1

shape=df.shape

print("exchanges:{}, \nparameters:{}".format(shape[0],shape[1]))
inp=input("do you want to see the file (y/n) :")
if(inp=="yes"or inp=='y'):
    display(df)
inp=input("do you want to save the file in excel (y/n):")
if(inp=="yes"or inp=="y"):
    file_name=file[:file.find(".")]
    df.to_excel(file_name+".xlsx")
inp=input("do you also want to save the file in csv (y/n):")
if(inp=="yes"or inp=="y"):
    df.to_csv(file_name+".csv")
print("saved")
# Out:
# enter the file that you want to open:ayushi-shrey.txt
# exchanges:21238,
# parameters:4
# do you want to see the file (y/n) :y
#            date         time  sender  \
# 0      20/04/19  12:32:36 AM  Sugli💯
# 1      20/04/19  12:32:36 AM  Sugli💯
# 2      20/04/19  10:18:40 AM  Ayushi
# 3      20/04/19  10:18:49 AM  Ayushi
# 4      20/04/19  02:08:05 PM  Sugli💯
# 5      20/04/19  02:08:11 PM  Sugli💯
# 6      20/04/19  07:01:22 PM  Ayushi
# 7      20/04/19  07:02:38 PM  Ayushi
# 8      20/04/19  07:02:52 PM  Ayushi
# 9      20/04/19  07:03:19 PM  Sugli💯
# 10     20/04/19  07:03:59 PM  Sugli💯
# 11     20/04/19  07:06:36 PM  Ayushi
# 12     20/04/19  07:06:40 PM  Ayushi
# 13     20/04/19  07:06:45 PM  Ayushi
# 14     20/04/19  07:06:51 PM  Ayushi
# 15     22/04/19  10:34:37 PM  Sugli💯
# 16     22/04/19  10:34:41 PM  Sugli💯
# 17     22/04/19  10:36:16 PM  Ayushi
# 18     22/04/19  10:38:00 PM  Sugli💯
# 19     22/04/19  10:38:07 PM  Sugli💯
# 20     22/04/19  11:27:10 PM  Ayushi
# 21     22/04/19  11:27:20 PM  Ayushi
# 22     22/04/19  11:27:37 PM  Sugli💯
# 23     22/04/19  11:28:12 PM  Ayushi
# 24     22/04/19  11:28:31 PM  Ayushi
# 25     22/04/19  11:28:40 PM  Sugli💯
# 26     22/04/19  11:28:49 PM  Sugli💯
# 27     22/04/19  11:28:56 PM  Sugli💯
# 28     22/04/19  11:29:05 PM  Ayushi
# 29     22/04/19  11:30:39 PM  Sugli💯
# ...         ...          ...     ...
# 21208  03/07/19  01:31:08 AM  Ayushi
# 21209  03/07/19  01:31:08 AM  Ayushi
# 21210  04/07/19  12:55:49 AM  Ayushi
# 21211  04/07/19  12:55:49 AM  Ayushi
# 21212  04/07/19  12:56:13 AM  Ayushi
# 21213  04/07/19  12:56:13 AM  Ayushi
# 21214  05/07/19  09:26:40 PM  Ayushi
# 21215  05/07/19  09:26:43 PM  Ayushi
# 21216  05/07/19  09:26:43 PM  Ayushi
# 21217  05/07/19  09:27:37 PM  Sugli💯
# 21218  05/07/19  09:27:37 PM  Sugli💯
# 21219  05/07/19  09:43:30 PM  Sugli💯
# 21220  05/07/19  10:20:08 PM  Ayushi
# 21221  05/07/19  10:20:08 PM  Ayushi
# 21222  05/07/19  10:20:08 PM  Ayushi
# 21223  05/07/19  10:21:49 PM  Sugli💯
# 21224  05/07/19  10:22:00 PM  Sugli💯
# 21225  05/07/19  10:22:00 PM  Sugli💯
# 21226  05/07/19  10:24:58 PM  Sugli💯
# 21227  05/07/19  10:25:12 PM  Ayushi
# 21228  05/07/19  10:25:15 PM  Ayushi
# 21229  05/07/19  10:25:45 PM  Sugli💯
# 21230  05/07/19  10:26:44 PM  Sugli💯
# 21231  05/07/19  10:26:49 PM  Sugli💯
# 21232  05/07/19  10:26:57 PM  Sugli💯
# 21233  05/07/19  10:27:15 PM  Ayushi
# 21234  05/07/19  10:27:52 PM  Sugli💯
# 21235  05/07/19  10:27:58 PM  Sugli💯
# 21236  05/07/19  10:27:58 PM  Sugli💯
# 21237  05/07/19  10:27:58 PM  Sugli💯
#
#                                                  message
# 0      ‎Messages to this chat and calls are now secur...
# 1                                               called ?
# 2                                                    yup
# 3                               how are you feeling now?
# 4                                         much better re
# 5                                        ab kafibkam hai
# 6                              abhi not fully recovered?
# 7                                      sun karti hu call
# 8                                                 5 mins
# 9                                                     ok
# 10                        ek baar pehle message kar dena
# 11                                                   abe
# 12                                    tu busy aa rha hai
# 13                              mujhe car chlani hai phr
# 14                                    will it take time?
# 15                                                  oi ?
# 16                                          i called you
# 17                                       5 min mai karu?
# 18                                           got dekha ?
# 19                            nahi dekha to mat karna 😂😂
# 20                                                 haaww
# 21                                         nahi kar rhi😒
# 22                              yeah you should watch it
# 23                                       dlhungi dkhungi
# 24         clg mila toh usse phle dkh kar khtm kar dungi
# 25                                                   yes
# 26                                          khatam karna
# 27                                        warna spoilers
# 28                             college mila toh naa🤦🏼‍♀️
# 29                                                    ha
# ...                                                  ...
# 21208                          [‎[03/07/19,  9:40:39 PM]
# 21209                          [‎[03/07/19,  9:41:04 PM]
# 21210        abe yaha whatsapp nahi chl rha aaj dhang se
# 21211                      [download nahi ho rahi photo]
# 21212                                    I just got free
# 21213                                [just room par aai]
# 21214                                                bol
# 21215                                              jaldi
# 21216                          [‎[05/07/19,  9:27:33 PM]
# 21217                                          like this
# 21218                          [‎[05/07/19,  9:43:05 PM]
# 21219                                               wait
# 21220                                                  ?
# 21221                         [‎[05/07/19,  10:21:17 PM]
# 21222                         [‎[05/07/19,  10:21:42 PM]
# 21223                                this is for android
# 21224                       maybe tap on my image to see
# 21225                         [‎[05/07/19,  10:24:00 PM]
# 21226                                     whatsapp web ?
# 21227                                         udhr karu?
# 21228                                         itne mhnat
# 21229                                                ruk
# 21230                       https://youtu.be/Iq52RMQlvDo
# 21231                                        follow this
# 21232                             can be done in minutes
# 21233               abe itne kaaam hai vaise hi life mai
# 21234                 this does not require whatsapp web
# 21235                                watch you will know
# 21236                         [‎[05/07/19,  11:36:24 PM]
# 21237                         [‎[05/07/19,  11:56:41 PM]
#
# [21238 rows x 4 columns]
# do you want to save the file in excel (y/n):n
# do you also want to save the file in csv (y/n):n
# saved

# %%
# Out:
# True

# %%
# Out:
# 1
